# %% [markdown]
# # Springboard Data Science Career Track | Capstone Project 2

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this project we will build models to predict fraudulent credit card transactions. In this step we focus on collecting data, organizing it, and making sure it's well defined. The file creditcard.csv was obtained from Kaggle https://www.kaggle.com/mlg-ulb/creditcardfraud.
#
# Complete project proposal is in the documents directory.

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# We will read creditcard.csv file into a dataframe and then study it.
#
# Objectives:
# 1. Do we have the data to tackle the desired question?
# 2. Can we identify the required target value?
# 3. Identify potentially useful features?
# 4. Identify issues with the data?

# %% [markdown]
# ##### 1. Imports

# %%
# Imports
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# set sensible default parameters for matplotlib
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 100

# %%
# Read csv
df = pd.read_csv('../raw_data/creditcard.csv')

# %% [markdown]
# ##### 3. Let's look at the data

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
# Get the number of rows and columns
df.shape
# Out:
# (284807, 31)

# %%
# Get df Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %% [markdown]
# ##### 4. Check for missing values (NaN)

# %%
# Null values
df.isna().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# Our dataset does not have any null values. It has Time, Amount and Class columns along with 28 numerical columns labeled V1.. V28.

# %% [markdown]
# ##### Let us look at the distributions of values in our dataset.

# %%
df.describe().T
# Out:
#            count          mean           std         min           25%  \
# Time    284807.0  9.481386e+04  47488.145955    0.000000  54201.500000
# V1      284807.0  3.919560e-15      1.958696  -56.407510     -0.920373
# V2      284807.0  5.688174e-16      1.651309  -72.715728     -0.598550
# V3      284807.0 -8.769071e-15      1.516255  -48.325589     -0.890365
# V4      284807.0  2.782312e-15      1.415869   -5.683171     -0.848640
# V5      284807.0 -1.552563e-15      1.380247 -113.743307     -0.691597
# V6      284807.0  2.010663e-15      1.332271  -26.160506     -0.768296
# V7      284807.0 -1.694249e-15      1.237094  -43.557242     -0.554076
# V8      284807.0 -1.927028e-16      1.194353  -73.216718     -0.208630
# V9      284807.0 -3.137024e-15      1.098632  -13.434066     -0.643098
# V10     284807.0  1.768627e-15      1.088850  -24.588262     -0.535426
# V11     284807.0  9.170318e-16      1.020713   -4.797473     -0.762494
# ...

# %% [markdown]
# ##### Now let us look at the histograms of all columns.

# %%
df.hist(figsize=(25, 20))
plt.subplots_adjust(hspace=0.5);

# %% [markdown]
# Let's take a closer look at these columns and try to find additional information.

# %%
# Class, 
df.hist(column='Class', figsize=(6,4));

# %% [markdown]
# Values of class lie between 0 and 1. Most are either 0 or 1. Class appears to be categorical. Lets confirm.

# %%
df['Class'].unique()
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# Class is categorical. Probably a True(1)/False(0) column.

# %%
# Amount
df.hist(column='Amount', range=(0,500), figsize=(6,4));

# %%
df['Amount'].unique()
# Out:
# array([149.62,   2.69, 378.66, ..., 381.05, 337.54,  95.63])

# %%
df['Amount'].describe()
# Out:
# count    284807.000000
# mean         88.349619
# std         250.120109
# min           0.000000
# 25%           5.600000
# 50%          22.000000
# 75%          77.165000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
len (df.loc[df.Amount>200]), len (df.loc[df.Amount<=200])
# Out:
# (28837, 255970)

# %% [markdown]
# Amount has a long tailed distribution with the majority values between 0 and 200.

# %%
# Time
df.hist(column='Time', figsize=(6,4));

# %% [markdown]
# Time values range between 0 and 175000. Majority values appear to be in two buckets 40000-80000 and 120000-160000.

# %%
# Generate column list for V1... V28
col_list = ['V' + str(x) for x in range(1,29)]

# %%
# Plot histograms for each numeric feature
df.hist(column=col_list, figsize=(25, 20));

# %%
for col in col_list:
    print(col + '\t' + str(df[col].unique()))
# Out:
# V1	[-1.35980713  1.19185711 -1.35835406 ...  1.91956501 -0.24044005
#  -0.53341252]
# V2	[-0.07278117  0.26615071 -1.34016307 ... -0.30125385  0.53048251
#  -0.18973334]
# V3	[ 2.53634674  0.16648011  1.77320934 ... -3.24963981  0.70251023
#   0.70333737]
# V4	[ 1.37815522  0.44815408  0.37977959 ... -0.55782812  0.68979917
#  -0.50627124]
# V5	[-0.33832077  0.06001765 -0.50319813 ...  2.63051512 -0.37796113
#  -0.01254568]
# V6	[ 0.46238778 -0.08236081  1.80049938 ...  3.0312601   0.62370772
#  -0.64961669]
# V7	[ 0.23959855 -0.07880298  0.79146096 ... -0.29682653 -0.68617999
#   1.57700625]
# V8	[ 0.0986979   0.08510165  0.24767579 ...  0.70841718  0.67914546
#  -0.41465041]
# V9	[ 0.36378697 -0.25542513 -1.51465432 ...  0.43245405  0.39208671
#   0.48617951]
# V10	[ 0.09079417 -0.16697441  0.20764287 ... -0.48478176 -0.39912565
#  -0.91542665]
# V11	[-0.55159953  1.61272666  0.62450146 ...  0.41161374 -1.93384882
#  -1.04045834]
# ...

# %% [markdown]
# V1..V28 are numeric values. They do not appear to be categorical.

# %% [markdown]
# #####  Boxplots for numeric features V1... V28

# %%
df.boxplot(column=col_list, figsize=(25, 20));

# %% [markdown]
# #### Target feature

# %% [markdown]
# Our target feature is Class. Class is 1 when the transaction is fradulent, 0 othervise.
#
# Let's look at the seaborn boxplot for each numeric feature (V1... V28) with respect to Class.

# %%
# Melt dataframe for sns
df1 = df.melt(id_vars=['Class'], value_vars=col_list)
df1.head()
# Out:
#    Class variable     value
# 0      0       V1 -1.359807
# 1      0       V1  1.191857
# 2      0       V1 -1.358354
# 3      0       V1 -0.966272
# 4      0       V1 -1.158233

# %%
plt.subplots(figsize=(20, 10))
ax = sns.boxplot(x="variable", y="value",  hue="Class", data=df1)
plt.xticks(rotation='vertical')
plt.ylabel('Class')
plt.xlabel('Numeric Features');

# %% [markdown]
# That does not look readable. Perhaps if we scale the features, we might get a better view.

# %%
# Scale using MinMaxScaler
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df_scaled = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)
df_scaled
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 0       0.000000  0.935192  0.766490  0.881365  0.313023  0.763439  0.267669
# 1       0.000000  0.978542  0.770067  0.840298  0.271796  0.766120  0.262192
# 2       0.000006  0.935217  0.753118  0.868141  0.268766  0.762329  0.281122
# 3       0.000006  0.941878  0.765304  0.868484  0.213661  0.765647  0.275559
# 4       0.000012  0.938617  0.776520  0.864251  0.269796  0.762975  0.263984
# ...          ...       ...       ...       ...       ...       ...       ...
# 284802  0.999965  0.756448  0.873531  0.666991  0.160317  0.729603  0.236810
# 284803  0.999971  0.945845  0.766677  0.872678  0.219189  0.771561  0.273661
# 284804  0.999977  0.990905  0.764080  0.781102  0.227202  0.783425  0.293496
# 284805  0.999977  0.954209  0.772856  0.849587  0.282508  0.763172  0.269291
# 284806  1.000000  0.949232  0.765256  0.849601  0.229488  0.765632  0.256488
#
# ...

# %%
# Melt dataframe for sns
df1 = df_scaled.melt(id_vars=['Class'], value_vars=col_list)
df1.head()
# Out:
#    Class variable     value
# 0    0.0       V1  0.935192
# 1    0.0       V1  0.978542
# 2    0.0       V1  0.935217
# 3    0.0       V1  0.941878
# 4    0.0       V1  0.938617

# %%
# Generate boxplot for scaled data
plt.subplots(figsize=(20, 10))
ax = sns.boxplot(x="variable", y="value",  hue="Class", data=df1)
plt.xticks(rotation='vertical')
plt.ylabel('Class')
plt.xlabel('Numeric Features');

# %% [markdown]
# So far we have not looked at Amount and Time columns with respect to Class. We will look at them now.

# %%
df.boxplot(column='Amount', figsize=(6,4))

# %%
df.boxplot(column='Time', figsize=(6,4))

# %%
df.plot(kind='scatter', y='Amount', x='Class', figsize=(6,4));

# %% [markdown]
# Transactions where Class = 1 are less than 2500

# %%
df.plot(kind='scatter', y='Time', x='Class', figsize=(6,4));

# %% [markdown]
# There is no apparent relationship between Class and Time.
#
# Let's see if there is any relationship between Amount and Time.

# %%
df.plot(kind='scatter', x='Time', y='Amount', figsize=(6,4));

# %% [markdown]
# Large amounts have large time values (but not the other way around).

# %% [markdown]
# #####  Let's now look for duplicate rows

# %%
df_dup = df[df.duplicated(subset=None, keep='first')]
df_dup.shape
# Out:
# (1081, 31)

# %%
df_dup.head()
# Out:
#      Time        V1        V2        V3        V4        V5        V6  \
# 33   26.0 -0.529912  0.873892  1.347247  0.145457  0.414209  0.100223
# 35   26.0 -0.535388  0.865268  1.351076  0.147575  0.433680  0.086983
# 113  74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# 114  74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# 115  74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
#
#            V7        V8        V9  ...       V21       V22       V23  \
# 33   0.711206  0.176066 -0.286717  ...  0.046949  0.208105 -0.185548
# 35   0.693039  0.179742 -0.285642  ...  0.049526  0.206537 -0.187108
# 113 -0.036715  0.350995  0.118950  ...  0.102520  0.605089  0.023092
# 114 -0.036715  0.350995  0.118950  ...  0.102520  0.605089  0.023092
# 115 -0.036715  0.350995  0.118950  ...  0.102520  0.605089  0.023092
#
#           V24       V25       V26       V27       V28  Amount  Class
# ...

# %% [markdown]
# Looks like we have 1081 duplicate rows. Do we need to drop them??? We will decide later.

# %% [markdown]
# #### Summary

# %% [markdown]
# 1. Data file creditcard.csv1 has 284807 rows and 31 columns.
# 2. There are columns for Time, Amount and Class along with 28 numeric columns labeled V1... V28.
# 3. Data is not missing any values.
# 4. Class is categorical with value of either 0 or 1.
# 5. Class is our target feature. Fradulent transactions will have Class = 1, 0 otherwise.
# 6. Amount has a long tailed distribution which is expected.
# 7. Time values range between 0 and 175000. Majority values appear to be in two buckets 40000-80000 and 120000-160000.
# 8. There is no apparent relationship between Time and Class.
# 9. Amounts for Class = 1 are below 2500.
# 10. Larger amounts seem to have larges time values, but not the other way around.
# 11. There are 1081 duplicate rows. We don't know if they should be dropped.
